# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.options.display.max_rows = 10

# %%
grades = pd.read_excel('C:/Users/Administrator/Desktop/18191.xls')

# %%
grades
# Out:
#                 学号   姓名  学生标签  学制         开课学期  上课院系    班级名称      课程编号  \
# 0     201609010314  倪智鹏   NaN   4  2018-2019-1  计算机系  计科1703  80910262
# 1     201609010314  倪智鹏   NaN   4  2018-2019-1  计算机系  计科1703  70110104
# 2     201609010314  倪智鹏   NaN   4  2018-2019-1  计算机系  计科1703  80910218
# 3     201609010314  倪智鹏   NaN   4  2018-2019-1  计算机系  计科1703  80910169
# 4     201609010314  倪智鹏   NaN   4  2018-2019-1  计算机系  计科1703  80910273
# ...            ...  ...   ...  ..          ...   ...     ...       ...
# 3556  201709001032   周强   NaN   4  2018-2019-1  计算机系  信安1701  g0810770
# 3557  201709001032   周强   NaN   4  2018-2019-1  计算机系  信安1701  71010602
# 3558  201709001032   周强   NaN   4  2018-2019-1  计算机系  信安1701  71010606
# 3559  201709001032   周强   NaN   4  2018-2019-1  计算机系  信安1701  81010104
# 3560  201709001032   周强   NaN   4  2018-2019-1  计算机系  信安1701  70910116
#
#               课程名称  原成绩  ...  课程属性      学时   学分         开课单位           录入人  \
# ...

# %%
for index in grades.columns:
    if grades.isna().sum()[index] >= grades.shape[0]/2:
        del grades[index]

# %%
grades
# Out:
#                 学号   姓名  学制         开课学期  上课院系    班级名称      课程编号  \
# 0     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910262
# 1     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  70110104
# 2     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910218
# 3     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910169
# 4     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910273
# ...            ...  ...  ..          ...   ...     ...       ...
# 3556  201709001032   周强   4  2018-2019-1  计算机系  信安1701  g0810770
# 3557  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010602
# 3558  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010606
# 3559  201709001032   周强   4  2018-2019-1  计算机系  信安1701  81010104
# 3560  201709001032   周强   4  2018-2019-1  计算机系  信安1701  70910116
#
#               课程名称 总成绩    课程性质 课程属性      学时   学分         开课单位           录入人  \
# 0        编译技术课程设计B  及格    集中实践   任选  16(学时)  1.0      软件工程教研室  系统管理员[admin]
# ...

# %%
grades = grades.dropna()

# %%
grades
# Out:
#                 学号   姓名  学制         开课学期  上课院系    班级名称      课程编号  \
# 0     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910262
# 1     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  70110104
# 2     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910218
# 3     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910169
# 4     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910273
# ...            ...  ...  ..          ...   ...     ...       ...
# 3556  201709001032   周强   4  2018-2019-1  计算机系  信安1701  g0810770
# 3557  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010602
# 3558  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010606
# 3559  201709001032   周强   4  2018-2019-1  计算机系  信安1701  81010104
# 3560  201709001032   周强   4  2018-2019-1  计算机系  信安1701  70910116
#
#               课程名称 总成绩    课程性质 课程属性      学时   学分         开课单位           录入人  \
# 0        编译技术课程设计B  及格    集中实践   任选  16(学时)  1.0      软件工程教研室  系统管理员[admin]
# ...

# %%
grades['总成绩'].replace({'及格':60,'不及格':0,'不通过':0,'优':90,'良':80,'中':70},inplace=True)

# %%
grades
# Out:
#                 学号   姓名  学制         开课学期  上课院系    班级名称      课程编号  \
# 0     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910262
# 1     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  70110104
# 2     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910218
# 3     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910169
# 4     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910273
# ...            ...  ...  ..          ...   ...     ...       ...
# 3556  201709001032   周强   4  2018-2019-1  计算机系  信安1701  g0810770
# 3557  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010602
# 3558  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010606
# 3559  201709001032   周强   4  2018-2019-1  计算机系  信安1701  81010104
# 3560  201709001032   周强   4  2018-2019-1  计算机系  信安1701  70910116
#
#               课程名称 总成绩    课程性质 课程属性      学时   学分         开课单位           录入人  \
# 0        编译技术课程设计B  60    集中实践   任选  16(学时)  1.0      软件工程教研室  系统管理员[admin]
# ...

# %%
grades.loc[:,'总成绩'] = pd.to_numeric(grades.loc[:,'总成绩'])

# %%
type(grades.loc[3560,'总成绩'])
# Out:
# numpy.int64

# %%
for index,row in grades.iterrows():
    if grades.loc[index,'课程属性'] != '必修':
        grades = grades.drop(index)

# %%
grades
# Out:
#                 学号   姓名  学制         开课学期  上课院系    班级名称      课程编号       课程名称  \
# 7     201609010314  倪智鹏   4  2018-2019-1  计算机系  计科1703  80910122    算法与数据结构
# 16    201609010319  唐润文   4  2018-2019-1  计算机系  计科1703  80310119  模拟电子技术基础B
# 26    201609010319  唐润文   4  2018-2019-1  计算机系  计科1703  80910122    算法与数据结构
# 29    201609030218   汤捷   4  2018-2019-1  计算机系  网络1701  70910181   数据结构课程设计
# 30    201609030218   汤捷   4  2018-2019-1  计算机系  网络1701  70910116       数字逻辑
# ...            ...  ...  ..          ...   ...     ...       ...        ...
# 3555  201709001032   周强   4  2018-2019-1  计算机系  信安1701  70910182   数字逻辑课程设计
# 3557  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010602    大学物理(2)
# 3558  201709001032   周强   4  2018-2019-1  计算机系  信安1701  71010606    物理实验(2)
# 3559  201709001032   周强   4  2018-2019-1  计算机系  信安1701  81010104  概率论与数理统计B
# 3560  201709001032   周强   4  2018-2019-1  计算机系  信安1701  70910116       数字逻辑
#
# ...

# %%
everyone = grades['总成绩'].groupby(grades['姓名'])

# %%
everyone.describe()
# Out:
#            count       mean        std   min    25%   50%    75%    max
# 姓名
# 习梦圆         10.0  92.900000   5.130519  86.0  90.00  90.5  97.50  100.0
# 于烨璐         10.0  89.600000   8.329332  68.0  90.00  90.5  94.00   99.0
# 于雪           9.0  74.888889  19.400029  44.0  60.00  75.0  90.00  100.0
# 伊卜拉伊木·库尔班   11.0  62.545455  15.845275  34.0  61.00  66.0  70.00   84.0
# 伊恒正         10.0  73.900000   8.517303  60.0  68.25  72.5  80.75   88.0
# ...          ...        ...        ...   ...    ...   ...    ...    ...
# 黄玉婷         11.0  76.000000  12.513992  62.0  66.50  72.0  82.00  100.0
# 黎文茜         10.0  84.600000   5.541761  77.0  80.50  84.0  86.75   96.0
# 齐国梁         10.0  89.300000   6.074537  78.0  86.00  90.0  90.75   99.0
# 龙云飞         10.0  85.500000   6.654155  78.0  80.25  84.0  89.50  100.0
# 龙俊文         12.0  69.416667  15.588214  43.0  61.50  68.0  79.25   96.0
#
# [287 rows x 8 columns]

# %%
pd.options.display.max_rows = 50

# %%
everyone.mean().sort_values(ascending=False)
# Out:
# 姓名
# 邓紫臻         93.500000
# 习梦圆         92.900000
# 李百强         92.900000
# 常悦          92.400000
# 张丹          92.100000
# 张方缘         92.000000
# 胡湘婧         91.900000
# 李季凡         91.800000
# 曹越          91.600000
# 刘锴          91.500000
# 喻靖壹         91.500000
# 聂雅诗         91.400000
# 李双佼         91.400000
# 张原野         91.300000
# 余正秦         90.500000
# 罗驰          90.500000
# 林金坤         90.300000
# 杨馨云         90.000000
# 冯瑶玮         89.700000
# 于烨璐         89.600000
# 王勇攀         89.600000
# 王子龙         89.500000
# 齐国梁         89.300000
# 王硕          89.300000
# 姜定          89.200000
#               ...
# 周仁          56.846154
# 孙熙佐         56.357143
# 李想          56.333333
# 柴松岳         55.750000
# 李泽堂         55.571429
# 李瑞          55.142857
# 贾照宇         54.076923
# 魏晓璐         53.785714
# 劳田丰         53.642857
# 杨文轩         51.933333
# 杨丽          51.642857
# 贾志昂         50.928571
# 唐海林         50.666667
# 许星河         48.857143
# 宋文飞         48.692308
# ...

# %% [markdown]
# 去了选修课平均成绩反而更高了...大佬们还是大佬们
